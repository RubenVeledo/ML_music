# %% [markdown]
# <p style="text-align: center;">
#    <img src="../img/encabezado.jpg" alt="Música retro" width="600" height="300">
# </p>

# %% [markdown]
# ## 🎶 **Ecos del pasado: estrategias de clasificación musical para aumentar el engagement de usuarios en Spotify** 🎵

# %% [markdown]
# ##### 📚 Proyecto que combina la nostalgia de las décadas pasadas con modelos de machine learning para optimizar la experiencia de los usuarios en plataformas de streaming.

# %% [markdown]
# ---

# %% [markdown]
# #### 🎯 **Objetivo del proyecto:**
#
# El objetivo de este proyecto es utilizar modelos de machine learning para clasificar canciones según su década y analizar qué canciones modernas comparten la esencia de épocas pasadas. 🎶📊✨

# %% [markdown]
# ---

# %% [markdown]
# ##### 💡 **Beneficios esperados:**
#
# La idea es crear un sistema de clasificación que, a través de metadatos de las canciones, identifique canciones modernas que tengan la esencia y resuenen con el estilo de música de décadas pasadas, facilitando la creación de playlists personalizadas que atraigan a un público más adulto conectándolo con la música de hoy en día.

# %% [markdown]
# ---

# %% [markdown]
# #### 📊 **Datasets:**

# %% [markdown]
# **Dataset 1: Entrenamiento del modelo.**
#
# *Fuente: Kaggle.*

# %%
import pandas as pd

df_1 = pd.read_csv("../data/data.csv")

# %%
df_1.head(10)
# Out:
#                        id                                               name  \
# 0  0gNNToCW3qjabgTyBSjt3H                          !Que Vida! - Mono Version
# 1  0tMgFpOrXZR6irEOLNWwJL                                               "40"
# 2  2ZywW3VyVx6rrlrX75n3JB                                        "40" - Live
# 3  6DdWA7D1o5TU2kXWyCLcch                             "40" - Remastered 2008
# 4  3vMmwsAiLDCfyc1jl76lQE                             "40" - Remastered 2008
# 5  25Sd73fleKUVPNqITPZkn1                                               "45"
# 6  3mdPsKBeXxC4N6oKKZeBNy                                           "8" Teen
# 7  6CvreUbryAmXAUo35wuCQJ                                "A" You're Adorable
# 8  3cRrbXvGIeXvh1q5CO5pzl  "Addio, mio dolce amor!" from Edgar (Act III) ...
# 9  1fjKxQwdRQ8DFB4tKeAuFT                "Amarilli mia bella" - 1955 Version
#
#                                              artists  duration_ms  \
# ...

# %% [markdown]
# **Dataset 2: Generalización del modelo.**
#
# *Fuente: API Spotify.*

# %%
df_2 = pd.read_csv("../data/actual_tracks.csv")

# %%
df_2.head(10)
# Out:
#    Unnamed: 0                      id                  name  \
# 0           0  2kJRlOyrxsy7Ot3c5TZ8Q6  Meu Pedaço de Pecado
# 1           1  2QjOHCTQ1Jl3zawyYOpxh6       Sweater Weather
# 2           2  0VjIjW4GlUZAMYd2vXMi3b       Blinding Lights
# 3           3  7qEHsqek33rTcFNT9PFqLf     Someone You Loved
# 4           4  5CZ40GBx1sQ9agT82CLQCT               traitor
# 5           5  6Uj1ctrBOjOas8xZXGqKk4                 Woman
# 6           6  6UelLqGlWMcVH1E5c4H7lY      Watermelon Sugar
# 7           7  5QO79kh1waicV47BqGRL3g       Save Your Tears
# 8           8  3Wrjm47oTz2sjIgck11l5e               Beggin'
# 9           9  4RVwu0g32PAqgUiJoXsdF8     Happier Than Ever
#
#              artists  duration_ms release_date  year  popularity  explicit  \
# 0         João Gomes       157175   2021-06-01  2021           0     False
# 1  The Neighbourhood       240400   2013-04-22  2013          90     False
# 2         The Weeknd       200040   2020-03-20  2020          88     False
# ...
