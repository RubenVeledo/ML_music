# %% [markdown]
# ### Modelo básico. Decision Tree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize
from sklearn.feature_selection import SelectKBest, f_classif

# %%
df = pd.read_csv("../data/processed/processed_new_columns.csv", index_col=0)

# %%
df.head(5)
# Out:
#                        id                       name   artists  duration_ms  \
# 0  0gNNToCW3qjabgTyBSjt3H  !Que Vida! - Mono Version  ['Love']       220560
# 1  0tMgFpOrXZR6irEOLNWwJL                       "40"    ['U2']       157840
# 2  2ZywW3VyVx6rrlrX75n3JB                "40" - Live    ['U2']       226200
# 3  6DdWA7D1o5TU2kXWyCLcch     "40" - Remastered 2008    ['U2']       157667
# 4  3vMmwsAiLDCfyc1jl76lQE     "40" - Remastered 2008    ['U2']       157667
#
#   release_date  year  acousticness  danceability  energy  instrumentalness  \
# 0      11/1/66  1966        0.5250         0.600   0.540           0.00305
# 1      2/28/83  1983        0.2280         0.368   0.480           0.70700
# 2      8/20/83  1983        0.0998         0.272   0.684           0.01450
# 3      2/28/83  1983        0.1850         0.371   0.545           0.58200
# 4      2/28/83  1983        0.1850         0.371   0.545           0.58200
#
#    ...  explicit  artists_frequency  version_type                  base_name  \
# 0  ...         0                 51      Original  !Que Vida! - Mono Version
# 1  ...         0                218      Original                       "40"
# 2  ...         0                218          Live                     "40" -
# 3  ...         0                218      Remaster               "40" -  2008
# 4  ...         0                218      Remaster               "40" -  2008
#
#    version_Live  version_Original  version_Remaster  version_Remix  \
# 0             0                 1                 0              0
# 1             0                 1                 0              0
# 2             1                 0                 0              0
# 3             0                 0                 1              0
# 4             0                 0                 1              0
#
#    version_type_encoded  decade
# 0                     1    1960
# 1                     1    1980
# 2                     0    1980
# 3                     2    1980
# 4                     2    1980
#
# [5 rows x 28 columns]

# %% [markdown]
# Comenzamos tomando la decisión de centrarnos en las décadas desde 1950 hasta la de 2010, ambas incluidas. Esta decisión se fundamenta en dos motivos principales:
#
# - Motivo estadístico: El análisis descriptivo previo nos ha mostrado una descompensación de datos en función de las décadas. El periodo escogido sí tiene una representación equilibrada.
# - Motivo de negocio: Si el objetivo es que personas de edad avanzada puedan escuchar canciones de ahora que suenan a décadas pasadas, esas en las que ellos eran más jóvenes y descubrían nueva música, contar con décadas anteriores a los 50 no tendría mucho sentido por el propio perfil (edad) de los usuarios.

# %%
#Incluimos solo canciones entre las décadas de 1950 y 2010
df = df[(df['decade'] >= 1950) & (df['decade'] <= 2010)]

# %%
df.head(5)
# Out:
#                        id                       name   artists  duration_ms  \
# 0  0gNNToCW3qjabgTyBSjt3H  !Que Vida! - Mono Version  ['Love']       220560
# 1  0tMgFpOrXZR6irEOLNWwJL                       "40"    ['U2']       157840
# 2  2ZywW3VyVx6rrlrX75n3JB                "40" - Live    ['U2']       226200
# 3  6DdWA7D1o5TU2kXWyCLcch     "40" - Remastered 2008    ['U2']       157667
# 4  3vMmwsAiLDCfyc1jl76lQE     "40" - Remastered 2008    ['U2']       157667
#
#   release_date  year  acousticness  danceability  energy  instrumentalness  \
# 0      11/1/66  1966        0.5250         0.600   0.540           0.00305
# 1      2/28/83  1983        0.2280         0.368   0.480           0.70700
# 2      8/20/83  1983        0.0998         0.272   0.684           0.01450
# 3      2/28/83  1983        0.1850         0.371   0.545           0.58200
# 4      2/28/83  1983        0.1850         0.371   0.545           0.58200
#
#    ...  explicit  artists_frequency  version_type                  base_name  \
# 0  ...         0                 51      Original  !Que Vida! - Mono Version
# 1  ...         0                218      Original                       "40"
# 2  ...         0                218          Live                     "40" -
# 3  ...         0                218      Remaster               "40" -  2008
# 4  ...         0                218      Remaster               "40" -  2008
#
#    version_Live  version_Original  version_Remaster  version_Remix  \
# 0             0                 1                 0              0
# 1             0                 1                 0              0
# 2             1                 0                 0              0
# 3             0                 0                 1              0
# 4             0                 0                 1              0
#
#    version_type_encoded  decade
# 0                     1    1960
# 1                     1    1980
# 2                     0    1980
# 3                     2    1980
# 4                     2    1980
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 139848 entries, 0 to 169906
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    139848 non-null  object
#  1   name                  139848 non-null  object
#  2   artists               139848 non-null  object
#  3   duration_ms           139848 non-null  int64
#  4   release_date          139848 non-null  object
#  5   year                  139848 non-null  int64
#  6   acousticness          139848 non-null  float64
#  7   danceability          139848 non-null  float64
#  8   energy                139848 non-null  float64
#  9   instrumentalness      139848 non-null  float64
#  10  liveness              139848 non-null  float64
#  11  loudness              139848 non-null  float64
#  12  speechiness           139848 non-null  float64
#  13  tempo                 139848 non-null  float64
#  14  valence               139848 non-null  float64
#  15  mode                  139848 non-null  int64
#  16  key                   139848 non-null  int64
#  17  popularity            139848 non-null  int64
#  18  explicit              139848 non-null  int64
#  19  artists_frequency     139848 non-null  int64
#  20  version_type          139848 non-null  object
#  21  base_name             139848 non-null  object
#  22  version_Live          139848 non-null  int64
#  23  version_Original      139848 non-null  int64
#  24  version_Remaster      139848 non-null  int64
#  25  version_Remix         139848 non-null  int64
#  26  version_type_encoded  139848 non-null  int64
#  27  decade                139848 non-null  int64
# dtypes: float64(9), int64(13), object(6)
# memory usage: 30.9+ MB

# %%
df.columns
# Out:
# Index(['id', 'name', 'artists', 'duration_ms', 'release_date', 'year',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'mode',
#        'key', 'popularity', 'explicit', 'artists_frequency', 'version_type',
#        'base_name', 'version_Live', 'version_Original', 'version_Remaster',
#        'version_Remix', 'version_type_encoded', 'decade'],
#       dtype='object')

# %%
X = df[['duration_ms', 'acousticness', 'danceability', 'energy', 'instrumentalness',
      'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'mode',
      'key', 'popularity', 'explicit', 'version_type_encoded']]
y = df['decade']

# %%
#Dividimos en conjuntos para entrenamiento y pruebas
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, random_state=42)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (139848, 15)
# (27969, 15)
# (111879, 15)
# (27969,)
# (111879,)

# %%
model_1 = RandomForestClassifier(random_state=42)

# %%
#Entrenamiento
model_1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Evaluación
y_pred_1 = model_1.predict(X_test)
accuracy_1 = accuracy_score(y_test, y_pred_1)
precision_1 = precision_score(y_test, y_pred_1, average='macro')
recall_1 = recall_score(y_test, y_pred_1, average='macro')
f1_1 = f1_score(y_test, y_pred_1, average='macro')

# %%
print("Accuracy del modelo RandomForestClassifier:", accuracy_1)
print("Precisión (Precision):", precision_1)
print("Sensibilidad (Recall):", recall_1)
print("F1-Score:", f1_1)
# Out:
# Accuracy del modelo RandomForestClassifier: 0.5387785017742382
# Precisión (Precision): 0.5376827061842239
# Sensibilidad (Recall): 0.538792482723168
# F1-Score: 0.537014197311498

# %% [markdown]
# <mark>**Observación:**</mark> Mejora significativa: El modelo de Random Forest está funcionando mejor que el Decision Tree en todos los aspectos evaluados. Esto es consistente con la capacidad del Random Forest de capturar patrones complejos y reducir el sobreajuste en comparación con un solo árbol de decisión. No obstante, hay mucho margen de mejora.

# %%
print("Reporte de clasificación:")
print(classification_report(y_test, y_pred_1))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#         1950       0.81      0.77      0.79     16051
#         1960       0.52      0.56      0.54     15958
#         1970       0.43      0.43      0.43     15962
#         1980       0.48      0.42      0.45     16011
#         1990       0.40      0.36      0.38     15996
#         2000       0.46      0.52      0.49     15989
#         2010       0.66      0.72      0.69     15912
#
#     accuracy                           0.54    111879
#    macro avg       0.54      0.54      0.54    111879
# weighted avg       0.54      0.54      0.54    111879

# %%
#Matriz de confusión
print("Matriz de confusión:")
conf_matrix_1 = confusion_matrix(y_test, y_pred_1)
print(conf_matrix_1)
# Out:
# Matriz de confusión:
# [[12283  2941   398   109   167   106    47]
#  [ 2565  8980  2495   664   605   450   199]
#  [  124  2823  6808  3090  1642  1019   456]
#  [   75  1386  3364  6766  2610  1361   449]
#  [   32   803  1941  2781  5680  3449  1310]
#  [    8   328   586   561  2700  8284  3522]
#  [    1    80   138   114   641  3461 11477]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_1, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusión')
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.show()

# %% [markdown]
# <mark>**Observaciones:**</mark>
#
# - **Clase dominante (esquinas):** En las décadas más recientes y antiguas, como en las esquinas de la matriz (la primera y última filas y columnas), se puede ver que el modelo tiene un número notable de clasificaciones correctas, pero también muestra errores considerables.
# - **Confusión entre décadas cercanas.** El modelo tiende a confundir décadas consecutivas. Por ejemplo, en las filas centrales (correspondientes a décadas como los 70s, 80s y 90s), hay un número significativo de errores entre décadas vecinas. Esto puede indicar que las características en el estilo y producción musical de las canciones de esas décadas son similares, haciendo difícil la distinción.
# - **Desempeño general aceptable:** Aunque hay errores, el modelo básico está funcionando razonablemente bien, clasificando correctamente una gran cantidad de canciones en sus respectivas décadas.

# %%
#ROC-AUC multiclase (aunque es una métrica más favorable para modelos de clasificación binaria)
y_test_binarized_1 = label_binarize(y_test, classes=np.unique(y))
y_pred_proba_1 = model_1.predict_proba(X_test)
auc_score_1 = roc_auc_score(y_test_binarized_1, y_pred_proba_1, average='macro')
print("ROC-AUC Score (macro-average):", auc_score_1)
# Out:
# ROC-AUC Score (macro-average): 0.883774244626226

# %% [markdown]
# En un caso multiclase como este, se evalúa la capacidad del modelo para predecir correctamente cada clase en comparación con las demás.

# %% [markdown]
# ### Optimización 1: Feature importance

# %%
feature_importances = model_1.feature_importances_
features = X.columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# %%
importance_df
# Out:
#                  Feature  Importance
# 12            popularity    0.212400
# 6               loudness    0.095443
# 1           acousticness    0.093043
# 0            duration_ms    0.079389
# 3                 energy    0.075084
# 9                valence    0.068285
# 2           danceability    0.066546
# 7            speechiness    0.065886
# 8                  tempo    0.061214
# 5               liveness    0.059900
# 4       instrumentalness    0.054819
# 11                   key    0.038850
# 13              explicit    0.011164
# 10                  mode    0.010439
# 14  version_type_encoded    0.007537

# %%
X_reduc = df[['duration_ms', 'acousticness', 'danceability', 'energy', 
              'loudness', 'speechiness', 'tempo', 'valence', 'popularity',
              'liveness', 'instrumentalness']]

# %%
#Dividimos en conjuntos para entrenamiento y pruebas
X_train_reduc, X_test_reduc, y_train, y_test = train_test_split(X_reduc, y, train_size=0.2, random_state=42)

# %%
print(X.shape)
print(X_train_reduc.shape)
print(X_test_reduc.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (139848, 15)
# (27969, 11)
# (111879, 11)
# (27969,)
# (111879,)

# %%
model_2 = RandomForestClassifier(random_state=42)

# %%
#Entrenamiento
model_2.fit(X_train_reduc, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Evaluación
y_pred_2 = model_2.predict(X_test_reduc)
accuracy_2 = accuracy_score(y_test, y_pred_2)
precision_2 = precision_score(y_test, y_pred_2, average='macro')
recall_2 = recall_score(y_test, y_pred_2, average='macro')
f1_2 = f1_score(y_test, y_pred_2, average='macro')

# %%
print("Accuracy del modelo RandomForest:", accuracy_2)
print("Precisión (Precision):", precision_2)
print("Sensibilidad (Recall):", recall_2)
print("F1-Score:", f1_2)
# Out:
# Accuracy del modelo RandomForest: 0.5341306232626319
# Precisión (Precision): 0.5332950659307606
# Sensibilidad (Recall): 0.5341456719014508
# F1-Score: 0.5323381311296123

# %% [markdown]
# <mark>**Conclusiones:**</mark>
#
# - Haciendo una selección de variables (feature importance > 5) el modelo empeora mínimamente, lo que confirma que estas características tienen una importancia mínima en la predicción de la década.
#
# - La ligera caída en las métricas sugiere que las características eliminadas (key, explicit, mode, version_type_encoded) eran redundantes o no contribuían significativamente a la predicción.
#
# - La reducción en la complejidad del modelo puede ser beneficiosa en términos de eficiencia y generalización, aunque no se logró una mejora en el rendimiento.

# %% [markdown]
# ### Optimización 2: SelectKBest

# %%
k = 10
selector = SelectKBest(score_func=f_classif, k=k)
X_new = selector.fit_transform(X, y)
selected_features = X.columns[selector.get_support()]

# %%
print(f"Características seleccionadas con SelectKBest (top {k}):")
print(selected_features)
# Out:
# Características seleccionadas con SelectKBest (top 10):
# Index(['duration_ms', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'loudness', 'speechiness', 'valence', 'popularity',
#        'explicit'],
#       dtype='object')

# %%
X_train_k, X_test_k, y_train, y_test = train_test_split(X_new, y, train_size=0.2, random_state=42)

# %%
print(X.shape)
print(X_train_k.shape)
print(X_test_k.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (139848, 15)
# (27969, 10)
# (111879, 10)
# (27969,)
# (111879,)

# %%
model_3 = RandomForestClassifier(random_state=42)

# %%
#Entrenamiento
model_3.fit(X_train_k, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Evaluación
y_pred_3 = model_3.predict(X_test_k)
accuracy_3 = accuracy_score(y_test, y_pred_3)
precision_3 = precision_score(y_test, y_pred_3, average='macro')
recall_3 = recall_score(y_test, y_pred_3, average='macro')
f1_3 = f1_score(y_test, y_pred_3, average='macro')

# %%
print("Accuracy del modelo RandomForestClassifier:", accuracy_3)
print("Precisión (Precision):", precision_3)
print("Sensibilidad (Recall):", recall_3)
print("F1-Score:", f1_3)
# Out:
# Accuracy del modelo RandomForestClassifier: 0.5321195219835715
# Precisión (Precision): 0.5318931896638212
# Sensibilidad (Recall): 0.5321316961973799
# F1-Score: 0.5307430935109562

# %% [markdown]
# <mark>**Conclusión:**</mark> SelectKBest no mejoró significativamente el modelo. Esto sugiere que el modelo ya estaba utilizando las características más relevantes de manera efectiva.

# %% [markdown]
# ### Optimización 3: Hiperparametrización

# %%
#Configuración de hiperparámetros para RandomForest
param_grid = {
    "n_estimators" : [20, 50, 100],
    "max_depth": np.arange(3,8),
    "max_features": np.arange(2,5),
    "max_leaf_nodes": [10,15,20]
}

# %%
grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5, scoring='accuracy', verbose=2)
grid_search.fit(X_train_k, y_train)
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.2s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.2s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.5s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   4.5s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   5.3s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   4.5s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   9.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   2.4s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.0s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.2s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.1s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.6s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.5s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=3, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.2s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.7s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.6s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.6s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   3.1s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.5s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   0.7s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   0.7s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   0.8s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   0.8s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.0s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   1.7s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.0s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.0s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   1.6s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.2s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.2s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.2s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.9s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.6s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   3.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.4s
# [CV] END max_depth=3, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.6s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.4s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.7s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.8s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.9s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.4s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.6s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.1s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.1s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.0s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   2.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   2.9s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   3.6s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   2.9s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   2.6s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.1s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.1s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.2s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.3s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   2.8s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   2.5s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   2.6s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.1s
# [CV] END max_depth=3, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   2.6s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.4s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.2s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.1s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.8s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.0s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.7s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.7s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.0s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.0s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.6s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.3s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.8s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.7s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.7s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.7s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   1.5s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   1.5s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   1.5s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   1.6s
# [CV] END max_depth=4, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   1.8s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.8s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   3.3s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.7s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.7s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.8s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.3s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.0s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.2s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.1s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.1s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.1s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.2s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.2s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.3s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.4s
# [CV] END max_depth=4, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.4s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.7s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   2.7s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.1s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.2s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.5s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.7s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   1.0s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.9s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.8s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.7s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.8s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.2s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.3s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.0s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.1s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.9s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.7s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.9s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.0s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   2.7s
# [CV] END max_depth=4, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   2.7s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.2s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.2s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.8s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.8s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.8s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.8s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.9s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.0s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.9s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.1s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.2s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.9s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.1s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.1s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.3s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.2s
# [CV] END max_depth=5, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.7s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.7s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.6s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   3.1s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.5s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   3.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.6s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.3s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.3s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.6s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.3s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.1s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.6s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.2s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.3s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.3s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.3s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.6s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   3.1s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.7s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.5s
# [CV] END max_depth=5, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.5s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.4s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.7s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   4.1s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.1s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.8s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   4.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.7s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.7s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.7s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.7s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   1.7s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.0s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.9s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   3.8s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.6s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.7s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.8s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   1.8s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   2.2s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   1.9s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.9s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.8s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.0s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.0s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.9s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.7s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   6.2s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   4.0s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   4.3s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.4s
# [CV] END max_depth=5, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.4s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.1s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.7s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.5s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.4s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   3.7s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   3.1s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.1s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.9s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.8s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.3s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.1s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   0.9s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.2s
# [CV] END max_depth=6, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.6s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.5s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.3s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.3s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.6s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.6s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.1s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.9s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.9s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.6s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   1.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   1.3s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   1.0s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.8s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.5s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   2.4s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.8s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   3.0s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.9s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.8s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.8s
# [CV] END max_depth=6, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.8s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.2s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.4s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.4s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.7s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.7s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.0s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.2s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.2s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.4s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   3.5s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   3.7s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   3.9s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   3.4s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.7s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.6s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.7s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.8s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.0s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.8s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.8s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   1.8s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.7s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   4.2s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.8s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   3.7s
# [CV] END max_depth=6, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   4.0s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.2s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=20; total time=   0.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   0.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=50; total time=   1.0s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.0s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   1.9s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=15, n_estimators=100; total time=   2.1s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.5s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.1s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.2s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.1s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.2s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.4s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.3s
# [CV] END max_depth=7, max_features=2, max_leaf_nodes=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=20; total time=   0.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=10, n_estimators=100; total time=   2.9s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.3s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.5s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=50; total time=   1.5s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.5s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   2.8s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=15, n_estimators=100; total time=   3.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   1.0s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=20; total time=   0.8s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   2.2s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.5s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.4s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=50; total time=   1.6s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   2.9s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   3.1s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   3.0s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   3.0s
# [CV] END max_depth=7, max_features=3, max_leaf_nodes=20, n_estimators=100; total time=   3.0s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=20; total time=   0.6s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.7s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   2.0s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.7s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.8s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=50; total time=   1.7s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.8s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   3.7s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   4.0s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=10, n_estimators=100; total time=   4.0s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   1.0s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   1.0s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   1.1s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   1.1s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=20; total time=   1.0s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.2s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.3s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.6s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.3s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=50; total time=   2.5s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.2s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.8s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.3s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.2s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=15, n_estimators=100; total time=   4.7s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.8s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   1.1s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   1.5s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.8s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=20; total time=   0.7s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   5.2s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   3.7s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   3.6s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.7s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=50; total time=   2.8s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   5.5s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   5.4s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   5.9s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   5.2s
# [CV] END max_depth=7, max_features=4, max_leaf_nodes=20, n_estimators=100; total time=   5.2s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': array([3, 4, 5, 6, 7]),
#                          'max_features': array([2, 3, 4]),
#                          'max_leaf_nodes': [10, 15, 20],
#                          'n_estimators': [20, 50, 100]},
#              scoring='accuracy', verbose=2)

# %%
# Mostrar los mejores parámetros encontrados
grid_best_params = grid_search.best_params_
print("Mejores hiperparámetros:", grid_best_params)
# Out:
# Mejores hiperparámetros: {'max_depth': np.int64(7), 'max_features': np.int64(4), 'max_leaf_nodes': 20, 'n_estimators': 100}

# %%
#Evaluación del modelo
best_model = grid_search.best_estimator_
y_pred_4 = best_model.predict(X_test_k)
accuracy_4 = accuracy_score(y_test, y_pred_4)
precision_4 = precision_score(y_test, y_pred_4, average='macro')
recall_4 = recall_score(y_test, y_pred_4, average='macro')
f1_4 = f1_score(y_test, y_pred_4, average='macro')

# %%
print("Accuracy del modelo Decision Tree:", accuracy_4)
print("Precisión (Precision):", precision_4)
print("Sensibilidad (Recall):", recall_4)
print("F1-Score:", f1_4)
# Out:
# Accuracy del modelo Decision Tree: 0.48870654903958743
# Precisión (Precision): 0.4863329269998541
# Sensibilidad (Recall): 0.48876309901326404
# F1-Score: 0.4799143588684679

# %%
#Incompleta la hiperparametrización por un error
